# %% [markdown]
# <a href="https://colab.research.google.com/github/shrishti-04/DataAnalytics_Pandas_Numpy_Matplotlib_Seaborn/blob/master/Pandas_DataFrames_Fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. DEFINE A PANDAS DATAFRAME

# %%
import pandas as pd

# %%
# Let's define a two-dimensional Pandas DataFrame
# Note that you can create a pandas dataframe from a python dictionary

bank_info_df = pd.DataFrame({'Bank Client ID': [111, 122, 133, 144],
           'Bank Client Name': ['Jonathan Herd', 'Steve Buyers', 'Shrishti Tiwari', 'Francis Morris'],
           'Net Worth': [1500, 3400, 10000, 6000],
           'Years With Bank': [2, 4, 9, 6]})

bank_info_df
# Out:
#    Bank Client ID Bank Client Name  Net Worth  Years With Bank
# 0             111    Jonathan Herd       1500                2
# 1             122     Steve Buyers       3400                4
# 2             133  Shrishti Tiwari      10000                9
# 3             144   Francis Morris       6000                6

# %%
# Let's obtain the data type 

type(bank_info_df)
# Out:
# pandas.core.frame.DataFrame

# %%
# you can only view the first couple of rows using .head()

bank_info_df.head(2)
# Out:
#    Bank Client ID Bank Client Name  Net Worth  Years With Bank
# 0             111    Jonathan Herd       1500                2
# 1             122     Steve Buyers       3400                4

# %%
# you can only view the last couple of rows using .tail()

bank_info_df.tail(2)
# Out:
#    Bank Client ID Bank Client Name  Net Worth  Years With Bank
# 2             133  Shrishti Tiwari      10000                9
# 3             144   Francis Morris       6000                6

# %%
# You can obtain the shape of the DataFrame (#rows, #columns)

bank_info_df.shape
# Out:
# (4, 4)

# %%
# Obtain DataFrame information 

bank_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Bank Client ID    4 non-null      int64
#  1   Bank Client Name  4 non-null      object
#  2   Net Worth         4 non-null      int64
#  3   Years With Bank   4 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 256.0+ bytes

# %% [markdown]
# **MINI CHALLENGE #1:**
# - **A porfolio contains a collection of securities such as stocks, bonds and ETFs. Define a dataframe named 'portfolio_df' that holds 3 different stock ticker symbols, number of shares, and price per share (feel free to choose any stocks)**
# - **Calculate the total value of the porfolio including all stocks**

# %%
my_collection = pd.DataFrame({'Stock_Ticker_Symbol': ['AMZN', 'MSFT', 'AAPL'],
                              'Number Of Shares': [2, 3, 6],
                              'Price Per Shares': [230, 300, 450]})

# %%
total_collections = my_collection['Number Of Shares']*my_collection['Price Per Shares']
total_collections
# Out:
# 0     460
# 1     900
# 2    2700
# dtype: int64

# %%
total_collections.sum()
# Out:
# 4060

# %% [markdown]
# # 2. INPUTS (READ CSV AND HTML DATA)

# %%
# Pandas is used to read a csv file and store data in a DataFrame
bank_df = pd.read_csv('/content/bank_client_information.csv')

# %%
bank_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %%
# Read tabular data using read_html

house_price_df = pd.read_html('https://www.livingin-canada.com/house-prices-canada.html')

# %%
house_price_df[0]
# Out:
#                                                 City  \
# 0                                      Vancouver, BC
# 1                                       Toronto, Ont
# 2                                        Ottawa, Ont
# 3                                       Calgary, Alb
# 4                                      Montreal, Que
# 5                                        Halifax, NS
# 6                                       Regina, Sask
# 7                                    Fredericton, NB
# 8  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                  Average House Price  \
# 0                                         $1,036,000
# 1                                           $870,000
# 2                                           $479,000
# 3                                           $410,000
# 4                                           $435,000
# 5                                           $331,000
# 6                                           $254,000
# 7                                           $198,000
# 8  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                      12 Month Change
# 0                                           + 2.63 %
# 1                                            +10.2 %
# 2                                           + 15.4 %
# 3                                            – 1.5 %
# 4                                            + 9.3 %
# 5                                            + 3.6 %
# 6                                            – 3.9 %
# 7                                            – 4.3 %
# 8  (adsbygoogle = window.adsbygoogle || []).push(...

# %%
house_price_df[1]
# Out:
#                                              Province  \
# 0                                    British Columbia
# 1                                             Ontario
# 2                                             Alberta
# 3                                              Quebec
# 4                                            Manitoba
# 5                                        Saskatchewan
# 6                                         Nova Scotia
# 7                                Prince Edward Island
# 8                             Newfoundland / Labrador
# 9                                       New Brunswick
# 10                                   Canadian Average
# 11  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                   Average House Price  \
# 0                                            $736,000
# 1                                            $594,000
# 2                                            $353,000
# 3                                            $340,000
# 4                                            $295,000
# 5                                            $271,000
# 6                                            $266,000
# 7                                            $243,000
# 8                                            $236,000
# 9                                            $183,000
# 10                                           $488,000
# 11  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                       12 Month Change
# 0                                             + 7.6 %
# 1                                             – 3.2 %
# 2                                             – 7.5 %
# 3                                             + 7.6 %
# 4                                             – 1.4 %
# 5                                             – 3.8 %
# 6                                             + 3.5 %
# 7                                             + 3.0 %
# 8                                             – 1.6 %
# 9                                             – 2.2 %
# 10                                            – 1.3 %
# 11  (adsbygoogle = window.adsbygoogle || []).push(...

# %% [markdown]
# **MINI CHALLENGE #2:**
# - **Write a code that uses Pandas to read tabular US retirement data**
# - **You can use data from here: https://www.ssa.gov/oact/progdata/nra.html**

# %%
US_retirement_df = pd.read_html('https://www.ssa.gov/oact/progdata/nra.html')
US_retirement_df[0]
# Out:
#                                         Year of birth  \
# 0                                      1937 and prior
# 1                                                1938
# 2                                                1939
# 3                                                1940
# 4                                                1941
# 5                                                1942
# 6                                             1943-54
# 7                                                1955
# 8                                                1956
# 9                                                1957
# 10                                               1958
# 11                                               1959
# 12                                     1960 and later
# 13  Notes: 1. Persons born on January 1 of any yea...
#
#                                                   Age
# 0                                                  65
# 1                                     65 and 2 months
# 2                                     65 and 4 months
# 3                                     65 and 6 months
# 4                                     65 and 8 months
# 5                                    65 and 10 months
# 6                                                  66
# 7                                     66 and 2 months
# 8                                     66 and 4 months
# 9                                     66 and 6 months
# 10                                    66 and 8 months
# 11                                   66 and 10 months
# 12                                                 67
# 13  Notes: 1. Persons born on January 1 of any yea...

# %% [markdown]
# # 3. OUTPUTS (WRITE DATAFRAME INTO CSV)

# %%
# Let's define a two-dimensional Pandas DataFrame
# Note that you can create a pandas dataframe from a python dictionary

bank_df = pd.read_csv('/content/bank_client_information.csv')
bank_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %%
bank_df.to_csv('Sample_Bank_Info.csv', index = True)

# %% [markdown]
# **MINI CHALLENGE #3:**
# - **Use set index = False and rerun the cell. Comment on the output CSV.**
# - **Try to leverage the attribute compression and rerun the cell**

# %%
bank_df.to_csv('Sample_bank_info2.csv', index = False)

# %%
bank_df.to_csv('Sample_bank_info2.csv.gz', index = False, compression = 'gzip')

# %% [markdown]
# # 4. SETTING/RESETTING INDEX

# %%
# Pandas is used to read a csv file and store data in a DataFrame
# Note that a numeric index is being set by default

bank_df = pd.read_csv('/content/bank_client_information.csv')
bank_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %%
# You can assign a specific column to be the index as follows

bank_df.set_index('First Name', inplace = True)
bank_df
# Out:
#            Last Name                    Email Postal Code  Net Worth  \
# First Name
# Bird           Steve           bird@gmail.com     N94 3M0    5000.00
# Noah           Small       nsmall@hotmail.com     N8S 14K   10000.00
# Nina          Keller          azikez@gahew.mr     S1T 4E6    9072.02
# Chanel         Steve         chanel@gmail.com     N7T 3E6   11072.02
# Kate            Noor         kate@hotmail.com     K8N 5H6    5000.00
# Samer             Mo          samer@gmail.com     J7H 3HY  100000.00
# Heba          Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# Laila          Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# Joseph        Patton           daafeja@boh.jm     M6U 5U7    2629.13
# Noah           Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#             Years with Bank
# First Name
# Bird                      5
# Noah                      6
# Nina                      7
# Chanel                   10
# Kate                     22
# Samer                    26
# Heba                     11
# Laila                     3
# Joseph                    1
# Noah                     13

# %%
# You can go back and use numeric index using reset_index

bank_df.reset_index(inplace = True)
bank_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %%
# Alternatively, you can set the index name when you read the csv file as follows

bank_df = pd.read_csv('/content/bank_client_information.csv', index_col = 'Years with Bank')
bank_df
# Out:
#                 First Name Last Name                    Email Postal Code  \
# Years with Bank
# 5                    Bird      Steve           bird@gmail.com     N94 3M0
# 6                     Noah     Small       nsmall@hotmail.com     N8S 14K
# 7                     Nina    Keller          azikez@gahew.mr     S1T 4E6
# 10                 Chanel      Steve         chanel@gmail.com     N7T 3E6
# 22                    Kate      Noor         kate@hotmail.com     K8N 5H6
# 26                   Samer        Mo          samer@gmail.com     J7H 3HY
# 11                    Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8
# 3                    Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0
# 1                   Joseph    Patton           daafeja@boh.jm     M6U 5U7
# 13                    Noah     Moran        guutodi@bigwoc.kw     K2D 4M9
#
#                  Net Worth
# Years with Bank
# 5                  5000.00
# 6                 10000.00
# 7                  9072.02
# 10                11072.02
# 22                 5000.00
# 26               100000.00
# 11                50000.00
# 3                 20000.00
# 1                  2629.13
# 13                 8626.96

# %% [markdown]
# **MINI CHALLENGE #4:**
# - **Load the bank_client_information.csv and then set the "Last Name" column as the index**

# %%
bank_df = pd.read_csv('/content/bank_client_information.csv')
bank_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %%
bank_df = pd.read_csv('/content/bank_client_information.csv', index_col = 'Last Name')
bank_df
# Out:
#           First Name                    Email Postal Code  Net Worth  \
# Last Name
# Steve          Bird            bird@gmail.com     N94 3M0    5000.00
# Small           Noah       nsmall@hotmail.com     N8S 14K   10000.00
# Keller          Nina          azikez@gahew.mr     S1T 4E6    9072.02
# Steve        Chanel          chanel@gmail.com     N7T 3E6   11072.02
# Noor            Kate         kate@hotmail.com     K8N 5H6    5000.00
# Mo             Samer          samer@gmail.com     J7H 3HY  100000.00
# Ismail          Heba  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# Ahmed          Laila      Laila.a@hotmail.com     J8Y 3M0   20000.00
# Patton        Joseph           daafeja@boh.jm     M6U 5U7    2629.13
# Moran           Noah        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#            Years with Bank
# Last Name
# Steve                    5
# Small                    6
# Keller                   7
# Steve                   10
# Noor                    22
# Mo                      26
# Ismail                  11
# Ahmed                    3
# Patton                   1
# Moran                   13

# %% [markdown]
# # 5. SELECTING COLUMNS FROM A DATAFRAME

# %%
# Pandas is used to read a csv file and store data in a DataFrame

bank_df = pd.read_csv('/content/bank_client_information.csv')
bank_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %%
# Return a column from the DataFrame
# Note that the output will be a Pandas Series (you can automatically tell by the lack of formating)

bank_email_df = bank_df['Email']
bank_email_df
# Out:
# 0             bird@gmail.com
# 1         nsmall@hotmail.com
# 2            azikez@gahew.mr
# 3           chanel@gmail.com
# 4           kate@hotmail.com
# 5            samer@gmail.com
# 6    heba.ismail@hotmail.com
# 7        Laila.a@hotmail.com
# 8             daafeja@boh.jm
# 9          guutodi@bigwoc.kw
# Name: Email, dtype: object

# %%
# Confirm the datatype of sample
type(bank_email_df)
# Out:
# pandas.core.series.Series

# %%
# Alternatively, you can use the following syntax to do the same
# Note that this method will not work if there are spaces in the column names

bank_df.Email
# Out:
# 0             bird@gmail.com
# 1         nsmall@hotmail.com
# 2            azikez@gahew.mr
# 3           chanel@gmail.com
# 4           kate@hotmail.com
# 5            samer@gmail.com
# 6    heba.ismail@hotmail.com
# 7        Laila.a@hotmail.com
# 8             daafeja@boh.jm
# 9          guutodi@bigwoc.kw
# Name: Email, dtype: object

# %%
# Since the column name has spaces, this will be the only way that will work!

bank_df['Net Worth']
# Out:
# 0      5000.00
# 1     10000.00
# 2      9072.02
# 3     11072.02
# 4      5000.00
# 5    100000.00
# 6     50000.00
# 7     20000.00
# 8      2629.13
# 9      8626.96
# Name: Net Worth, dtype: float64

# %%
# Let's select multiple columns from the DataFrame
# you need to define a list containing all column names that you would like to select
# Note that since we collected more than one column, the output is a DataFrame (Notice the rich formatting)

samples = bank_df[['First Name', 'Net Worth']]
samples
# Out:
#   First Name  Net Worth
# 0      Bird     5000.00
# 1       Noah   10000.00
# 2       Nina    9072.02
# 3    Chanel    11072.02
# 4       Kate    5000.00
# 5      Samer  100000.00
# 6       Heba   50000.00
# 7      Laila   20000.00
# 8     Joseph    2629.13
# 9       Noah    8626.96

# %%
# Note that sample is now a DataFrame and not a Pandas Series (since it has multiple columns)
# You can use type to confirm or you can tell from the rich text formating

type(samples)
# Out:
# pandas.core.frame.DataFrame

# %%
# Alternatively, you can define a list first and then use it to select columns
my_samples = ['First Name', 'Net Worth', 'Years with Bank']
selected = bank_df[my_samples]
selected
# Out:
#   First Name  Net Worth  Years with Bank
# 0      Bird     5000.00                5
# 1       Noah   10000.00                6
# 2       Nina    9072.02                7
# 3    Chanel    11072.02               10
# 4       Kate    5000.00               22
# 5      Samer  100000.00               26
# 6       Heba   50000.00               11
# 7      Laila   20000.00                3
# 8     Joseph    2629.13                1
# 9       Noah    8626.96               13

# %%
# In order to access a given row in the dataframe

bank_df[0:3]
# Out:
#   First Name Last Name               Email Postal Code  Net Worth  \
# 0      Bird      Steve      bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small  nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller     azikez@gahew.mr     S1T 4E6    9072.02
#
#    Years with Bank
# 0                5
# 1                6
# 2                7

# %% [markdown]
# **MINI CHALLENGE #5:**
# - **Select the following columns from the dataFrame Net Worth, Years with Bank, and Postal Code**

# %%
bank_samples = ['Net Worth', 'Years with Bank', 'Postal Code']
bank_df[bank_samples]
# Out:
#    Net Worth  Years with Bank Postal Code
# 0    5000.00                5     N94 3M0
# 1   10000.00                6     N8S 14K
# 2    9072.02                7     S1T 4E6
# 3   11072.02               10     N7T 3E6
# 4    5000.00               22     K8N 5H6
# 5  100000.00               26     J7H 3HY
# 6   50000.00               11     K8Y 3M8
# 7   20000.00                3     J8Y 3M0
# 8    2629.13                1     M6U 5U7
# 9    8626.96               13     K2D 4M9

# %% [markdown]
# # 6. ADDING/DELETING COLUMNS TO DATAFRAME

# %%
# Pandas is used to read a csv file and store data in a DataFrame
bank_df = pd.read_csv('/content/bank_client_information.csv')
bank_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %%
# Let's assume that we want to add a new column to the dataframe
bank_df['Age'] = [25, 34, 27, 23, 29, 30, 33, 23, 38, 36]

# %%
bank_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank  Age
# 0                5   25
# 1                6   34
# 2                7   27
# 3               10   23
# 4               22   29
# 5               26   30
# 6               11   33
# 7                3   23
# 8                1   38
# 9               13   36

# %%
# You can also insert a new column in a given position 
bank_df.insert(2, column = 'credit Score', value = [680, 750, 330, 420, 890, 560, 450, 620, 745, 820])

# %%
bank_df
# Out:
#   First Name Last Name  credit Score                    Email Postal Code  \
# 0      Bird      Steve           680           bird@gmail.com     N94 3M0
# 1       Noah     Small           750       nsmall@hotmail.com     N8S 14K
# 2       Nina    Keller           330          azikez@gahew.mr     S1T 4E6
# 3    Chanel      Steve           420         chanel@gmail.com     N7T 3E6
# 4       Kate      Noor           890         kate@hotmail.com     K8N 5H6
# 5      Samer        Mo           560          samer@gmail.com     J7H 3HY
# 6       Heba    Ismail           450  heba.ismail@hotmail.com     K8Y 3M8
# 7      Laila     Ahmed           620      Laila.a@hotmail.com     J8Y 3M0
# 8     Joseph    Patton           745           daafeja@boh.jm     M6U 5U7
# 9       Noah     Moran           820        guutodi@bigwoc.kw     K2D 4M9
#
#    Net Worth  Years with Bank  Age
# 0    5000.00                5   25
# 1   10000.00                6   34
# 2    9072.02                7   27
# 3   11072.02               10   23
# 4    5000.00               22   29
# 5  100000.00               26   30
# 6   50000.00               11   33
# 7   20000.00                3   23
# 8    2629.13                1   38
# 9    8626.96               13   36

# %%
# Delete a column from a DataFrame

del bank_df['Last Name']

# %%
bank_df
# Out:
#   First Name  credit Score                    Email Postal Code  Net Worth  \
# 0      Bird            680           bird@gmail.com     N94 3M0    5000.00
# 1       Noah           750       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina           330          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel            420         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate           890         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer           560          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba           450  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila           620      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph           745           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah           820        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank  Age
# 0                5   25
# 1                6   34
# 2                7   27
# 3               10   23
# 4               22   29
# 5               26   30
# 6               11   33
# 7                3   23
# 8                1   38
# 9               13   36

# %%
# Remove a column from a DataFrame and store it somehwere else using pop

bank_df.pop('Years with Bank')
# Out:
# 0     5
# 1     6
# 2     7
# 3    10
# 4    22
# 5    26
# 6    11
# 7     3
# 8     1
# 9    13
# Name: Years with Bank, dtype: int64

# %% [markdown]
# **MINI CHALLENGE #6:**
# - **load the bank_client_information.csv file and perform the following: (assume any reasonable values)**
#     - **Add a column indicating whether the client has a mortgage or not**
#     - **Add a column indicating the value of mortage in dollars**

# %%
bank_df['Has Mortgage'] = [1, 0, 0, 0, 1, 1, 0, 0, 0, 1]
bank_df['Mortgage Rate'] = [35000, 0, 0, 0, 40000, 38000, 0, 0, 0, 48000]
bank_df
# Out:
#   First Name  credit Score                    Email Postal Code  Net Worth  \
# 0      Bird            680           bird@gmail.com     N94 3M0    5000.00
# 1       Noah           750       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina           330          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel            420         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate           890         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer           560          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba           450  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila           620      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph           745           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah           820        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Age  Has Mortgage  Mortgage Rate
# 0   25             1          35000
# 1   34             0              0
# 2   27             0              0
# 3   23             0              0
# 4   29             1          40000
# 5   30             1          38000
# 6   33             0              0
# 7   23             0              0
# 8   38             0              0
# 9   36             1          48000

# %% [markdown]
# # 7. LABEL-BASED ELEMENTS SELECTION FROM A DATAFRAME ".LOC()"

# %%
# Load the csv file and set the last name as the index

bank_df = pd.read_csv('/content/bank_client_information.csv', index_col = 'Last Name')
bank_df
# Out:
#           First Name                    Email Postal Code  Net Worth  \
# Last Name
# Steve          Bird            bird@gmail.com     N94 3M0    5000.00
# Small           Noah       nsmall@hotmail.com     N8S 14K   10000.00
# Keller          Nina          azikez@gahew.mr     S1T 4E6    9072.02
# Steve        Chanel          chanel@gmail.com     N7T 3E6   11072.02
# Noor            Kate         kate@hotmail.com     K8N 5H6    5000.00
# Mo             Samer          samer@gmail.com     J7H 3HY  100000.00
# Ismail          Heba  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# Ahmed          Laila      Laila.a@hotmail.com     J8Y 3M0   20000.00
# Patton        Joseph           daafeja@boh.jm     M6U 5U7    2629.13
# Moran           Noah        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#            Years with Bank
# Last Name
# Steve                    5
# Small                    6
# Keller                   7
# Steve                   10
# Noor                    22
# Mo                      26
# Ismail                  11
# Ahmed                    3
# Patton                   1
# Moran                   13

# %%
# Sort the dataframe in an alphabetical order

bank_df.sort_index(inplace = True)
bank_df
# Out:
#           First Name                    Email Postal Code  Net Worth  \
# Last Name
# Ahmed          Laila      Laila.a@hotmail.com     J8Y 3M0   20000.00
# Ismail          Heba  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# Keller          Nina          azikez@gahew.mr     S1T 4E6    9072.02
# Mo             Samer          samer@gmail.com     J7H 3HY  100000.00
# Moran           Noah        guutodi@bigwoc.kw     K2D 4M9    8626.96
# Noor            Kate         kate@hotmail.com     K8N 5H6    5000.00
# Patton        Joseph           daafeja@boh.jm     M6U 5U7    2629.13
# Small           Noah       nsmall@hotmail.com     N8S 14K   10000.00
# Steve          Bird            bird@gmail.com     N94 3M0    5000.00
# Steve        Chanel          chanel@gmail.com     N7T 3E6   11072.02
#
#            Years with Bank
# Last Name
# Ahmed                    3
# Ismail                  11
# Keller                   7
# Mo                      26
# Moran                   13
# Noor                    22
# Patton                   1
# Small                    6
# Steve                    5
# Steve                   10

# %%
# loc is used to filter rows and columns
# loc is label-based meaning you need to give a name of the rows (or columns) that you are interested in selecting
# Note that iloc is "integer index-based" meaning you can filter rows/columns by their integer index.
# Note that we obtained a Series because last name "Small" existed only once in the dataframe

bank_df.loc['Patton']
# Out:
# First Name                 Joseph
# Email              daafeja@boh.jm
# Postal Code               M6U 5U7
# Net Worth                 2629.13
# Years with Bank                 1
# Name: Patton, dtype: object

# %%
# Note that you got a DataFrame back since Last Name 'Steve' existed more than one in the DataFrame

bank_df.loc['Steve']
# Out:
#           First Name             Email Postal Code  Net Worth  Years with Bank
# Last Name
# Steve          Bird     bird@gmail.com     N94 3M0    5000.00                5
# Steve        Chanel   chanel@gmail.com     N7T 3E6   11072.02               10

# %%
# Note that you can select multiple rows using "colon :"
# Note that this is inclusive! meaning that "Ahmed" and "Patton" were selected in the output DataFrame
# Headsup: this will be different if we use integer based index such as iloc()

bank_df.loc['Ahmed':'Patton']
# Out:
#           First Name                    Email Postal Code  Net Worth  \
# Last Name
# Ahmed          Laila      Laila.a@hotmail.com     J8Y 3M0   20000.00
# Ismail          Heba  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# Keller          Nina          azikez@gahew.mr     S1T 4E6    9072.02
# Mo             Samer          samer@gmail.com     J7H 3HY  100000.00
# Moran           Noah        guutodi@bigwoc.kw     K2D 4M9    8626.96
# Noor            Kate         kate@hotmail.com     K8N 5H6    5000.00
# Patton        Joseph           daafeja@boh.jm     M6U 5U7    2629.13
#
#            Years with Bank
# Last Name
# Ahmed                    3
# Ismail                  11
# Keller                   7
# Mo                      26
# Moran                   13
# Noor                    22
# Patton                   1

# %%
# Select all elements up to and including 'Keller' index

bank_df.loc[:'Keller']
# Out:
#           First Name                    Email Postal Code  Net Worth  \
# Last Name
# Ahmed          Laila      Laila.a@hotmail.com     J8Y 3M0   20000.00
# Ismail          Heba  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# Keller          Nina          azikez@gahew.mr     S1T 4E6    9072.02
#
#            Years with Bank
# Last Name
# Ahmed                    3
# Ismail                  11
# Keller                   7

# %%
# if you want to select multiple rows, you can pass them as a list as follows
my_list = ['Moran', 'Steve', 'Ismail', 'Mo']
bank_df.loc[my_list]
# Out:
#           First Name                    Email Postal Code  Net Worth  \
# Last Name
# Moran           Noah        guutodi@bigwoc.kw     K2D 4M9    8626.96
# Steve          Bird            bird@gmail.com     N94 3M0    5000.00
# Steve        Chanel          chanel@gmail.com     N7T 3E6   11072.02
# Ismail          Heba  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# Mo             Samer          samer@gmail.com     J7H 3HY  100000.00
#
#            Years with Bank
# Last Name
# Moran                   13
# Steve                    5
# Steve                   10
# Ismail                  11
# Mo                      26

# %%
# You can also randomly select a fraction of the DataFrame
# Setting axis = 0 means rows, setting index = 1 means columns

bank_df.sample(n = 4, axis = 0)
# Out:
#           First Name                    Email Postal Code  Net Worth  \
# Last Name
# Keller          Nina          azikez@gahew.mr     S1T 4E6    9072.02
# Small           Noah       nsmall@hotmail.com     N8S 14K   10000.00
# Steve          Bird            bird@gmail.com     N94 3M0    5000.00
# Ismail          Heba  heba.ismail@hotmail.com     K8Y 3M8   50000.00
#
#            Years with Bank
# Last Name
# Keller                   7
# Small                    6
# Steve                    5
# Ismail                  11

# %%
# return a percentage (Ex: 30%) of the rows 

bank_df.sample(frac = 0.3, axis = 0)
# Out:
#           First Name                    Email Postal Code  Net Worth  \
# Last Name
# Ahmed          Laila      Laila.a@hotmail.com     J8Y 3M0   20000.00
# Moran           Noah        guutodi@bigwoc.kw     K2D 4M9    8626.96
# Ismail          Heba  heba.ismail@hotmail.com     K8Y 3M8   50000.00
#
#            Years with Bank
# Last Name
# Ahmed                    3
# Moran                   13
# Ismail                  11

# %% [markdown]
# **MINI CHALLENGE #7:**
# - **Load the csv data and use the "first name" column as the index**
# - **Randomly select 2 rows from the DataFrame. Rerun the code and ensure that random rows are being selected**

# %%
bank_df = pd.read_csv('/content/bank_client_information.csv', index_col = 'First Name')
bank_df
# Out:
#            Last Name                    Email Postal Code  Net Worth  \
# First Name
# Bird           Steve           bird@gmail.com     N94 3M0    5000.00
# Noah           Small       nsmall@hotmail.com     N8S 14K   10000.00
# Nina          Keller          azikez@gahew.mr     S1T 4E6    9072.02
# Chanel         Steve         chanel@gmail.com     N7T 3E6   11072.02
# Kate            Noor         kate@hotmail.com     K8N 5H6    5000.00
# Samer             Mo          samer@gmail.com     J7H 3HY  100000.00
# Heba          Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# Laila          Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# Joseph        Patton           daafeja@boh.jm     M6U 5U7    2629.13
# Noah           Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#             Years with Bank
# First Name
# Bird                      5
# Noah                      6
# Nina                      7
# Chanel                   10
# Kate                     22
# Samer                    26
# Heba                     11
# Laila                     3
# Joseph                    1
# Noah                     13

# %%
bank_df.sample(n=2, axis=0)
# Out:
#            Last Name                    Email Postal Code  Net Worth  \
# First Name
# Heba          Ismail  heba.ismail@hotmail.com     K8Y 3M8    50000.0
# Kate            Noor         kate@hotmail.com     K8N 5H6     5000.0
#
#             Years with Bank
# First Name
# Heba                     11
# Kate                     22

# %% [markdown]
# # 8. INTEGER INDEX-BASED ELEMENTS SELECTION FROM A DATAFRAME "iLOC()"

# %%
# Load the CSV file with default index

bank_df = pd.read_csv('/content/bank_client_information.csv')
bank_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %%
# You can access rows with their numeric index using iloc

bank_df.iloc[4]
# Out:
# First Name                     Kate
# Last Name                      Noor
# Email              kate@hotmail.com
# Postal Code                 K8N 5H6
# Net Worth                    5000.0
# Years with Bank                  22
# Name: 4, dtype: object

# %%
# You can access multiple rows with their numeric index using iloc and colon :
# Note that using iloc is exclusive, meaning that we did not include the last element (quite confusing I know!)
# We went from index = 2 up until and not including index 5 so index 2,3, and 4 are the one selected

bank_df.iloc[2:6]
# Out:
#   First Name Last Name             Email Postal Code  Net Worth  \
# 2       Nina    Keller   azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve  chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor  kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo   samer@gmail.com     J7H 3HY  100000.00
#
#    Years with Bank
# 2                7
# 3               10
# 4               22
# 5               26

# %%
# all up until and not including index 4

bank_df.iloc[:4]
# Out:
#   First Name Last Name               Email Postal Code  Net Worth  \
# 0      Bird      Steve      bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small  nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller     azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve    chanel@gmail.com     N7T 3E6   11072.02
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10

# %%
# Multiple elements are selected using a list of indexes 

elements = [3, 6, 7, 9]
bank_df.iloc[elements]
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 3               10
# 6               11
# 7                3
# 9               13

# %%
# Slicing a piece of the dataframe by selecting which row and column you would like to select

bank_df.iloc[2, 0:3]
bank_df.iloc[5, 2:5]
# Out:
# Email          samer@gmail.com
# Postal Code            J7H 3HY
# Net Worth             100000.0
# Name: 5, dtype: object

# %% [markdown]
# **MINI CHALLENGE #8:**
# - **Write a code that selects the last two rows in the DataFrame using two different methods**

# %%
bank_df.iloc[-2:]
# Out:
#   First Name Last Name              Email Postal Code  Net Worth  \
# 8     Joseph    Patton     daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran  guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 8                1
# 9               13

# %%
bank_df.iloc[8:]
# Out:
#   First Name Last Name              Email Postal Code  Net Worth  \
# 8     Joseph    Patton     daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran  guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 8                1
# 9               13

# %% [markdown]
# # 9. BROADCASTING OPERATIONS & SETTING NEW DATAFRAME VALUES

# %%
# Pandas is used to read a csv file and store data in a DataFrame

bank_df = pd.read_csv('/content/bank_client_information.csv')
bank_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %%
# Let's assume that we want to update the networth of all our customers by $1000

bank_df['Net Worth'] = bank_df['Net Worth'] + 1000
bank_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    6000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   11000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6   10072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   12072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    6000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  101000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   51000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   21000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    3629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    9626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %%
bank_df['Net Worth'] = bank_df['Net Worth'].add(1000)
bank_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    7000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   12000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6   11072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   13072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    7000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  102000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   52000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   22000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    4629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9   10626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %%
# Alternatively, you can add or subtract as follows

bank_df['Net Worth'] = bank_df['Net Worth'].sub(1000)
bank_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    6000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   11000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6   10072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   12072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    6000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  101000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   51000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   21000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    3629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    9626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %%
# Let's convert from USD to CAD using the exchange rate 1 USD = 1.3 CAD 

bank_df['Net Worth [CAD]'] = bank_df['Net Worth'].mul(1.3)
bank_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    6000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   11000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6   10072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   12072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    6000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  101000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   51000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   21000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    3629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    9626.96
#
#    Years with Bank  Net Worth [CAD]
# 0                5         7800.000
# 1                6        14300.000
# 2                7        13093.626
# 3               10        15693.626
# 4               22         7800.000
# 5               26       131300.000
# 6               11        66300.000
# 7                3        27300.000
# 8                1         4717.869
# 9               13        12515.048

# %%
# Decided to update the email address of a given customer

bank_df.iloc[4, 2] = 'noor.kate@gmail.com'

# %%
bank_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    6000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   11000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6   10072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   12072.02
# 4       Kate      Noor      noor.kate@gmail.com     K8N 5H6    6000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  101000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   51000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   21000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    3629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    9626.96
#
#    Years with Bank  Net Worth [CAD]
# 0                5         7800.000
# 1                6        14300.000
# 2                7        13093.626
# 3               10        15693.626
# 4               22         7800.000
# 5               26       131300.000
# 6               11        66300.000
# 7                3        27300.000
# 8                1         4717.869
# 9               13        12515.048

# %%
# Let's assume we want to update the networth of two clients

bank_df.iloc[[3,4], [4]] = [14074.00, 8000.00]

# %%
bank_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    6000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   11000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6   10072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   14074.00
# 4       Kate      Noor      noor.kate@gmail.com     K8N 5H6    8000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  101000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   51000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   21000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    3629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    9626.96
#
#    Years with Bank  Net Worth [CAD]
# 0                5         7800.000
# 1                6        14300.000
# 2                7        13093.626
# 3               10        15693.626
# 4               22         7800.000
# 5               26       131300.000
# 6               11        66300.000
# 7                3        27300.000
# 8                1         4717.869
# 9               13        12515.048

# %% [markdown]
# **MINI CHALLENGE #9:**
# - **Let's assume that all clients in the bank has been investing their assets in a broad S&P500 ETF. The market has been performing really well and clients networth has increased by 12% annualy. Calculate the sum of all client's networth.**

# %%
bank_df = pd.read_csv('/content/bank_client_information.csv')
bank_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %%
bank_df['Net Worth New'] = bank_df['Net Worth'].mul(1.12)
bank_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank  Net Worth New
# 0                5      5600.0000
# 1                6     11200.0000
# 2                7     10160.6624
# 3               10     12400.6624
# 4               22      5600.0000
# 5               26    112000.0000
# 6               11     56000.0000
# 7                3     22400.0000
# 8                1      2944.6256
# 9               13      9662.1952

# %%
bank_df['Net Worth New'].sum()
# Out:
# 247968.14560000002

# %%
print('Therefore the total clients networth = ${}'.format(bank_df['Net Worth New'].sum()))
# Out:
# Therefore the total clients networth = $247968.14560000002

# %% [markdown]
# # 10. SORTING AND ORDERING

# %%
# Let's read a CSV file using Pandas as follows

bank_df = pd.read_csv('/content/bank_client_information.csv')
bank_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %%
# You can sort the values in the dataframe according to number of years with bank

bank_df.sort_values(by = 'Years with Bank')
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
#
#    Years with Bank
# 8                1
# 7                3
# 0                5
# 1                6
# 2                7
# 3               10
# 6               11
# 9               13
# 4               22
# 5               26

# %%
# Note that nothing changed in memory! you have to make sure that inplace is set to True
bank_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %%
# Set inplace = True to ensure that change has taken place in memory 

bank_df.sort_values(by = 'Years with Bank', inplace = True)

# %%
# Note that now the change (ordering) took place 

bank_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
#
#    Years with Bank
# 8                1
# 7                3
# 0                5
# 1                6
# 2                7
# 3               10
# 6               11
# 9               13
# 4               22
# 5               26

# %%
# You can sort the values in a descending order as follows

bank_df.sort_values(by = 'Years with Bank', inplace = True, ascending = False)
bank_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
#
#    Years with Bank
# 5               26
# 4               22
# 9               13
# 6               11
# 3               10
# 2                7
# 1                6
# 0                5
# 7                3
# 8                1

# %%
# You can sort the dataframe with index instead of values as follows

bank_df.sort_index(inplace = True)
bank_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %%
bank_df['Rank'] = bank_df['Net Worth'].rank(ascending = True).astype('int')

# %%
bank_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank  Rank
# 0                5     2
# 1                6     6
# 2                7     5
# 3               10     7
# 4               22     2
# 5               26    10
# 6               11     9
# 7                3     8
# 8                1     1
# 9               13     4

# %% [markdown]
# **MINI CHALLENGE #10:**
# - **Sort customers by networth instead of years with bank. Make sure to update values in-memory.**

# %%
bank_df.sort_values(by = 'Net Worth', inplace = True)

# %%
bank_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
#
#    Years with Bank  Rank
# 8                1     1
# 0                5     2
# 4               22     2
# 9               13     4
# 2                7     5
# 1                6     6
# 3               10     7
# 7                3     8
# 6               11     9
# 5               26    10

# %% [markdown]
# # 11. PANDAS WITH FUNCTIONS

# %%
# Let's read a CSV file using Pandas as follows
bank_df = pd.read_csv('/content/bank_client_information.csv')
bank_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %%
# Define a function that increases all clients networth by a fixed value of 10% (for simplicity sake) 

def networth_update(value):
  return value * 1.1

# %%
# You can apply a function to the DataFrame 

bank_df['Net Worth'] = bank_df['Net Worth'].apply(networth_update)
bank_df
# Out:
#   First Name Last Name                    Email Postal Code   Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5500.000
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   11000.000
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9979.222
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   12179.222
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5500.000
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  110000.000
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   55000.000
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   22000.000
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2892.043
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    9489.656
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %%
bank_df['Name Length'] = bank_df['First Name'].apply(len)

# %%
bank_df
# Out:
#   First Name Last Name                    Email Postal Code   Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5500.000
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   11000.000
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9979.222
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   12179.222
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5500.000
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  110000.000
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   55000.000
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   22000.000
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2892.043
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    9489.656
#
#    Years with Bank  Name Length
# 0                5            5
# 1                6            4
# 2                7            4
# 3               10            7
# 4               22            4
# 5               26            5
# 6               11            4
# 7                3            5
# 8                1            6
# 9               13            4

# %% [markdown]
# **MINI CHALLENGE #11:**
# - **Define a function that doubles an argument and adds $100**
# - **Apply the function to the Net Worth Column in the DataFrame**
# - **Calculate the updated total networth of all clients combined**

# %%
def updated_networth(balance):
  return balance * 2 + 100

# %%
bank_df['Net Worth'] = bank_df['Net Worth'].apply(updated_networth)
bank_df
# Out:
#   First Name Last Name                    Email Postal Code   Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0   11100.000
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   22100.000
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6   20058.444
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   24458.444
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6   11100.000
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  220100.000
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8  110100.000
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   44100.000
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    5884.086
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9   19079.312
#
#    Years with Bank  Name Length
# 0                5            5
# 1                6            4
# 2                7            4
# 3               10            7
# 4               22            4
# 5               26            5
# 6               11            4
# 7                3            5
# 8                1            6
# 9               13            4

# %%
total_networth = bank_df['Net Worth'].sum()
total_networth
# Out:
# 488080.286

# %% [markdown]
# # 12. PANDAS OPERATIONS/FILTERING

# %%
# Let's read a CSV file using Pandas as follows
bank_df = pd.read_csv('/content/bank_client_information.csv')
bank_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %%
# Pick certain rows that satisfy a certain criteria 

loyal_df = bank_df[ (bank_df['Years with Bank'] >= 10) ]
loyal_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 3               10
# 4               22
# 5               26
# 6               11
# 9               13

# %%
# Pick certain rows that satisfy 2 or more critirea

mask1 = bank_df['Years with Bank'] >= 10
mask2 = bank_df['Net Worth'] >= 50000

filter = bank_df[mask1 & mask2]
filter
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 5      Samer        Mo          samer@gmail.com     J7H 3HY   100000.0
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8    50000.0
#
#    Years with Bank
# 5               26
# 6               11

# %%
# Pick certain rows that satisfy a certain criteria 

filtered_value = bank_df[(bank_df['First Name'] == 'Heba')]
filtered_value
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8    50000.0
#
#    Years with Bank
# 6               11

# %%
collected_value = bank_df[ (bank_df['Last Name'].isin(['Steve', 'Mo'])) ]
collected_value
# Out:
#   First Name Last Name             Email Postal Code  Net Worth  \
# 0      Bird      Steve    bird@gmail.com     N94 3M0    5000.00
# 3    Chanel      Steve  chanel@gmail.com     N7T 3E6   11072.02
# 5      Samer        Mo   samer@gmail.com     J7H 3HY  100000.00
#
#    Years with Bank
# 0                5
# 3               10
# 5               26

# %%
# values that fall between a given range

range_value = bank_df[ (bank_df['Net Worth'].between(10000, 100000)) ]
range_value
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
#
#    Years with Bank
# 1                6
# 3               10
# 5               26
# 6               11
# 7                3

# %%
  # Delete duplicated rows
bank_df['Last Name'].duplicated(keep = False)
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: Last Name, dtype: bool

# %%
# add a tilde symbol ~

duplicate_value = bank_df[~ bank_df['Last Name'].duplicated(keep = False)]
duplicate_value
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 1                6
# 2                7
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %%
# Let's read a CSV file using Pandas as follows

bank_df= pd.read_csv('/content/bank_client_information.csv')
bank_df

# Drop duplicates

bank_df.drop_duplicates(subset = ['Last Name'], inplace = True)

# %%
bank_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %%
from numpy import where
# We can also filter the Dataframe using the where method as follows
# Note that all rows that don't satisfy this critirea are set to NaN

bank_df = pd.read_csv('/content/bank_client_information.csv')
filter = bank_df['Years with Bank'] >= 10

bank_df.where(filter)
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0        NaN       NaN                      NaN         NaN        NaN
# 1        NaN       NaN                      NaN         NaN        NaN
# 2        NaN       NaN                      NaN         NaN        NaN
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7        NaN       NaN                      NaN         NaN        NaN
# 8        NaN       NaN                      NaN         NaN        NaN
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0              NaN
# 1              NaN
# 2              NaN
# 3             10.0
# 4             22.0
# 5             26.0
# 6             11.0
# 7              NaN
# 8              NaN
# 9             13.0

# %% [markdown]
# **MINI CHALLENGE #12:**
# - **Using "bank_client_df" DataFrame, leverage pandas operations to only select high networth individuals with minimum $15000**
# - **What is the combined networth for all customers with 15000+ networth?**

# %%
high_value = bank_df[ (bank_df['Net Worth'] >= 15000) ]
high_value
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 5      Samer        Mo          samer@gmail.com     J7H 3HY   100000.0
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8    50000.0
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0    20000.0
#
#    Years with Bank
# 5               26
# 6               11
# 7                3

# %%
total_high_value = high_value['Net Worth'].sum()
total_high_value
# Out:
# 170000.0

# %%
print('The total networth above 15000 = $ {}'.format(total_high_value))
# Out:
# The total networth above 15000 = $ 170000.0

# %% [markdown]
# # 13. FEATURE ENGINEERING AND DEALING WITH MISSING DATASET

# %%
# Let's read a CSV file using Pandas as follows

employee_df = pd.read_csv('Human_Resources.csv')
employee_df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                1.0  ...                         1            80
# 1                2.0  ...                         4            80
# 2                4.0  ...                         2            80
# 3                5.0  ...                         3            80
# 4                7.0  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465          2061.0  ...                         3            80
# 1466          2062.0  ...                         1            80
# 1467          2064.0  ...                         2            80
# 1468          2065.0  ...                         4            80
# 1469          2068.0  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]

# %%
# first, let's locate rows that have Null values
employee_df.isnull()
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0     False      False           False      False       False
# 1     False      False           False      False       False
# 2     False      False           False      False       False
# 3     False      False           False      False       False
# 4     False      False           False      False       False
# ...     ...        ...             ...        ...         ...
# 1465  False      False           False      False       False
# 1466  False      False           False      False       False
# 1467  False      False           False      False       False
# 1468  False      False           False      False       False
# 1469  False      False           False      False       False
#
#       DistanceFromHome  Education  EducationField  EmployeeCount  \
# 0                False      False           False          False
# 1                False      False           False          False
# 2                False      False           False          False
# 3                False      False           False          False
# 4                False      False           False          False
# ...                ...        ...             ...            ...
# 1465             False      False           False          False
# 1466             False      False           False          False
# 1467             False      False           False          False
# 1468             False      False           False          False
# 1469             False      False           False          False
#
#       EmployeeNumber  ...  RelationshipSatisfaction  StandardHours  \
# 0              False  ...                     False          False
# 1              False  ...                     False          False
# 2              False  ...                     False          False
# 3              False  ...                     False          False
# 4              False  ...                     False          False
# ...              ...  ...                       ...            ...
# 1465           False  ...                     False          False
# 1466           False  ...                     False          False
# 1467           False  ...                     False          False
# 1468           False  ...                     False          False
# 1469           False  ...                     False          False
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                False              False                  False
# 1                False              False                  False
# 2                False              False                  False
# 3                False              False                  False
# 4                False              False                  False
# ...                ...                ...                    ...
# 1465             False              False                  False
# 1466             False              False                  False
# 1467             False              False                  False
# 1468             False              False                  False
# 1469             False              False                  False
#
#       WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0               False           False               False
# 1               False           False               False
# 2               False           False               False
# 3               False           False               False
# 4               False           False               False
# ...               ...             ...                 ...
# 1465            False           False               False
# 1466            False           False               False
# 1467            False           False               False
# 1468            False           False               False
# 1469            False           False               False
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                       False                 False
# 1                       False                 False
# 2                       False                 False
# 3                       False                 False
# 4                       False                 False
# ...                       ...                   ...
# 1465                    False                 False
# 1466                    False                 False
# 1467                    False                 False
# 1468                    False                 False
# 1469                    False                 False
#
# [1470 rows x 35 columns]

# %%
# first, let's locate rows that have Null values

employee_df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  1
# DistanceFromHome            0
# Education                   0
# EducationField              1
# EmployeeCount               0
# EmployeeNumber              1
# EnvironmentSatisfaction     0
# Gender                      1
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     1
# JobSatisfaction             0
# MaritalStatus               1
# MonthlyIncome               3
# MonthlyRate                 2
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           1
# PerformanceRating           1
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
# Drop any row that contains a Null value 
# Note that the size of the dataframe has been reduced by 7 elements
# Note that all will be used to drop rows that contains only Null values

employee_df.dropna(how = 'any', inplace = True)

# %%
employee_df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# 5                    2          2  Life Sciences              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                1.0  ...                         1            80
# 2                4.0  ...                         2            80
# 3                5.0  ...                         3            80
# 4                7.0  ...                         4            80
# 5                8.0  ...                         3            80
# ...              ...  ...                       ...           ...
# 1465          2061.0  ...                         3            80
# 1466          2062.0  ...                         1            80
# 1467          2064.0  ...                         2            80
# 1468          2065.0  ...                         4            80
# 1469          2068.0  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# 5                    0                  8                      2
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# 5                  2               7                  7
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# 5                           3                     6
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1463 rows x 35 columns]

# %%
# Let's read a CSV file using Pandas as follows

employee_df = pd.read_csv('Human_Resources.csv')
employee_df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                1.0  ...                         1            80
# 1                2.0  ...                         4            80
# 2                4.0  ...                         2            80
# 3                5.0  ...                         3            80
# 4                7.0  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465          2061.0  ...                         3            80
# 1466          2062.0  ...                         1            80
# 1467          2064.0  ...                         2            80
# 1468          2065.0  ...                         4            80
# 1469          2068.0  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]

# %%
# We can also indicate which columns we want to drop NaN from

employee_df.dropna(how = 'any', inplace = True, subset = ['MonthlyIncome', 'MonthlyRate', 'PercentSalaryHike'])

# %%
employee_df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# 5                    2          2  Life Sciences              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                1.0  ...                         1            80
# 2                4.0  ...                         2            80
# 3                5.0  ...                         3            80
# 4                7.0  ...                         4            80
# 5                8.0  ...                         3            80
# ...              ...  ...                       ...           ...
# 1465          2061.0  ...                         3            80
# 1466          2062.0  ...                         1            80
# 1467          2064.0  ...                         2            80
# 1468          2065.0  ...                         4            80
# 1469          2068.0  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# 5                    0                  8                      2
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# 5                  2               7                  7
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# 5                           3                     6
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1465 rows x 35 columns]

# %%
# Let's read a CSV file using Pandas as follows

employee_df = pd.read_csv('Human_Resources.csv')
employee_df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                1.0  ...                         1            80
# 1                2.0  ...                         4            80
# 2                4.0  ...                         2            80
# 3                5.0  ...                         3            80
# 4                7.0  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465          2061.0  ...                         3            80
# 1466          2062.0  ...                         1            80
# 1467          2064.0  ...                         2            80
# 1468          2065.0  ...                         4            80
# 1469          2068.0  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]

# %%
# Calculate the average monthly income
employee_df['MonthlyIncome'].mean()
# Out:
# 6505.155419222904

# %%
# You can use Fillna to fill a given column with a certain value

employee_df['MonthlyIncome'].fillna(employee_df['MonthlyIncome'].mean(), inplace = True)

# %%
employee_df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                1.0  ...                         1            80
# 1                2.0  ...                         4            80
# 2                4.0  ...                         2            80
# 3                5.0  ...                         3            80
# 4                7.0  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465          2061.0  ...                         3            80
# 1466          2062.0  ...                         1            80
# 1467          2064.0  ...                         2            80
# 1468          2065.0  ...                         4            80
# 1469          2068.0  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]

# %%
employee_df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  1
# DistanceFromHome            0
# Education                   0
# EducationField              1
# EmployeeCount               0
# EmployeeNumber              1
# EnvironmentSatisfaction     0
# Gender                      1
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     1
# JobSatisfaction             0
# MaritalStatus               1
# MonthlyIncome               0
# MonthlyRate                 2
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           1
# PerformanceRating           1
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %% [markdown]
# **MINI CHALLENGE #13:**
# - **Calculate the median monthly rate. Use the calculated median values to fill out missing data. Confirm that the process is successful**

# %%
employee_df = pd.read_csv('Human_Resources.csv')
employee_df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                1.0  ...                         1            80
# 1                2.0  ...                         4            80
# 2                4.0  ...                         2            80
# 3                5.0  ...                         3            80
# 4                7.0  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465          2061.0  ...                         3            80
# 1466          2062.0  ...                         1            80
# 1467          2064.0  ...                         2            80
# 1468          2065.0  ...                         4            80
# 1469          2068.0  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]

# %%
employee_df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  1
# DistanceFromHome            0
# Education                   0
# EducationField              1
# EmployeeCount               0
# EmployeeNumber              1
# EnvironmentSatisfaction     0
# Gender                      1
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     1
# JobSatisfaction             0
# MaritalStatus               1
# MonthlyIncome               3
# MonthlyRate                 2
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           1
# PerformanceRating           1
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
employee_df['MonthlyRate'].median()
# Out:
# 14235.5

# %%
employee_df['MonthlyRate'].fillna(employee_df['MonthlyRate'].median(), inplace = True)

# %%
employee_df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                1.0  ...                         1            80
# 1                2.0  ...                         4            80
# 2                4.0  ...                         2            80
# 3                5.0  ...                         3            80
# 4                7.0  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465          2061.0  ...                         3            80
# 1466          2062.0  ...                         1            80
# 1467          2064.0  ...                         2            80
# 1468          2065.0  ...                         4            80
# 1469          2068.0  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]

# %%
employee_df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  1
# DistanceFromHome            0
# Education                   0
# EducationField              1
# EmployeeCount               0
# EmployeeNumber              1
# EnvironmentSatisfaction     0
# Gender                      1
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     1
# JobSatisfaction             0
# MaritalStatus               1
# MonthlyIncome               3
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           1
# PerformanceRating           1
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %% [markdown]
# # 14. CHANGE DATATYPES

# %%
# Let's read a CSV file using Pandas as follows

employee_df = pd.read_csv('Human_Resources.csv')
employee_df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                1.0  ...                         1            80
# 1                2.0  ...                         4            80
# 2                4.0  ...                         2            80
# 3                5.0  ...                         3            80
# 4                7.0  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465          2061.0  ...                         3            80
# 1466          2062.0  ...                         1            80
# 1467          2064.0  ...                         2            80
# 1468          2065.0  ...                         4            80
# 1469          2068.0  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]

# %%
employee_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1469 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1469 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1469 non-null   float64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1469 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1469 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1469 non-null   object
#  18  MonthlyIncome             1467 non-null   float64
#  19  MonthlyRate               1468 non-null   float64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1469 non-null   float64
#  24  PerformanceRating         1469 non-null   float64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: float64(5), int64(21), object(9)
# memory usage: 402.1+ KB

# %%
# Let's convert the hourly rate from int64 to float64

employee_df['HourlyRate'] = employee_df['HourlyRate'].astype('float')

# %%
employee_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1469 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1469 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1469 non-null   float64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1469 non-null   object
#  12  HourlyRate                1470 non-null   float64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1469 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1469 non-null   object
#  18  MonthlyIncome             1467 non-null   float64
#  19  MonthlyRate               1468 non-null   float64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1469 non-null   float64
#  24  PerformanceRating         1469 non-null   float64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: float64(6), int64(20), object(9)
# memory usage: 402.1+ KB

# %%
# Since we have limited number of classes, we can use the categrory datatype
# check the memory usage with the info method to ensure that the size has been reduced

employee_df['PerformanceRating'] = employee_df['PerformanceRating'].astype('category')
employee_df['RelationshipSatisfaction'] = employee_df['RelationshipSatisfaction'].astype('category')

# %%
# Notice the reduction in size

employee_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1469 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1469 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1469 non-null   float64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1469 non-null   object
#  12  HourlyRate                1470 non-null   float64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1469 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1469 non-null   object
#  18  MonthlyIncome             1467 non-null   float64
#  19  MonthlyRate               1468 non-null   float64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1469 non-null   float64
#  24  PerformanceRating         1469 non-null   category
#  25  RelationshipSatisfaction  1470 non-null   category
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: category(2), float64(5), int64(19), object(9)
# memory usage: 382.3+ KB

# %% [markdown]
# **MINI CHALLENGE #14:**
# - **Convert the BusinessTravel column to category format.**
# - **How many KBytes in memory have been saved?**

# %%
employee_df = pd.read_csv('Human_Resources.csv')
employee_df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                1.0  ...                         1            80
# 1                2.0  ...                         4            80
# 2                4.0  ...                         2            80
# 3                5.0  ...                         3            80
# 4                7.0  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465          2061.0  ...                         3            80
# 1466          2062.0  ...                         1            80
# 1467          2064.0  ...                         2            80
# 1468          2065.0  ...                         4            80
# 1469          2068.0  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]

# %%
employee_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1469 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1469 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1469 non-null   float64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1469 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1469 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1469 non-null   object
#  18  MonthlyIncome             1467 non-null   float64
#  19  MonthlyRate               1468 non-null   float64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1469 non-null   float64
#  24  PerformanceRating         1469 non-null   float64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: float64(5), int64(21), object(9)
# memory usage: 402.1+ KB

# %%
employee_df['BusinessTravel'] = employee_df['BusinessTravel'].astype('category')
employee_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   category
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1469 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1469 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1469 non-null   float64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1469 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1469 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1469 non-null   object
#  18  MonthlyIncome             1467 non-null   float64
#  19  MonthlyRate               1468 non-null   float64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1469 non-null   float64
#  24  PerformanceRating         1469 non-null   float64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: category(1), float64(5), int64(21), object(8)
# memory usage: 392.2+ KB
